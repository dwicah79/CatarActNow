# %% [markdown]
# # Connect to drive

# %%
# This code mounts your Google Drive to the Google Colab environment.
# It allows you to access files stored in your Google Drive directly from Colab.
# After running this code, you will be prompted to authorize Colab to access your Google Drive.
# Once authorized, you can read from and write to your Google Drive as if it were a local directory.

from google.colab import drive
drive.mount('/content/drive')
# Out:
# Mounted at /content/drive

# %% [markdown]
# # Import the required libraries

# %%
# Import Library
import tensorflow as tf
from tensorflow.keras.preprocessing.image import ImageDataGenerator
from tensorflow.keras.applications import InceptionResNetV2
from tensorflow.keras import layers, models
import matplotlib.pyplot as plt
import seaborn as sns
import numpy as np
from sklearn.metrics import confusion_matrix, classification_report
import math

# %% [markdown]
# # Preparation

# %%
# Define Directories
train_dir = "/content/drive/MyDrive/Bangkit 2024/Split_Augmentation/Dataset/train"
valid_dir = "/content/drive/MyDrive/Bangkit 2024/Split_Augmentation/Dataset/valid"
test_dir = "/content/drive/MyDrive/Bangkit 2024/Split_Augmentation/Dataset/test"

# %%
# Image Data Generators
train_datagen = ImageDataGenerator(preprocessing_function=tf.keras.applications.inception_resnet_v2.preprocess_input)
valid_datagen = ImageDataGenerator(preprocessing_function=tf.keras.applications.inception_resnet_v2.preprocess_input)
test_datagen = ImageDataGenerator(preprocessing_function=tf.keras.applications.inception_resnet_v2.preprocess_input)

train_batches = train_datagen.flow_from_directory(train_dir, target_size=(229, 229), batch_size=32, class_mode='categorical')
valid_batches = valid_datagen.flow_from_directory(valid_dir, target_size=(229, 229), batch_size=32, class_mode='categorical')
test_batches = test_datagen.flow_from_directory(test_dir, target_size=(229, 229), batch_size=32, class_mode='categorical', shuffle=False)
# Out:
# Found 4011 images belonging to 3 classes.
# Found 1284 images belonging to 3 classes.
# Found 1290 images belonging to 3 classes.

# %% [markdown]
# # Load Pretrained Model

# %%
# Retrieve One Batch of Images and Labels
imgs, labels = next(train_batches)

# %%
# Load Pretrained Model
base_model = InceptionResNetV2(weights='imagenet', include_top=False, input_shape=(229, 229, 3))
base_model.summary()
print(type(base_model))
# Out:
# Downloading data from https://storage.googleapis.com/tensorflow/keras-applications/inception_resnet_v2/inception_resnet_v2_weights_tf_dim_ordering_tf_kernels_notop.h5
# 219055592/219055592 [==============================] - 1s 0us/step
# Model: "inception_resnet_v2"
# __________________________________________________________________________________________________
#  Layer (type)                Output Shape                 Param #   Connected to
# ==================================================================================================
#  input_1 (InputLayer)        [(None, 229, 229, 3)]        0         []
#
#  conv2d (Conv2D)             (None, 114, 114, 32)         864       ['input_1[0][0]']
#
#  batch_normalization (Batch  (None, 114, 114, 32)         96        ['conv2d[0][0]']
#  Normalization)
#
#  activation (Activation)     (None, 114, 114, 32)         0         ['batch_normalization[0][0]']
#
#  conv2d_1 (Conv2D)           (None, 112, 112, 32)         9216      ['activation[0][0]']
#
#  batch_normalization_1 (Bat  (None, 112, 112, 32)         96        ['conv2d_1[0][0]']
#  chNormalization)
#
#  activation_1 (Activation)   (None, 112, 112, 32)         0         ['batch_normalization_1[0][0]'
#                                                                     ]
#
#  conv2d_2 (Conv2D)           (None, 112, 112, 64)         18432     ['activation_1[0][0]']
#
#  batch_normalization_2 (Bat  (None, 112, 112, 64)         192       ['conv2d_2[0][0]']
#  chNormalization)
#
#  activation_2 (Activation)   (None, 112, 112, 64)         0         ['batch_normalization_2[0][0]'
#                                                                     ]
#
#  max_pooling2d (MaxPooling2  (None, 55, 55, 64)           0         ['activation_2[0][0]']
#  D)
#
#  conv2d_3 (Conv2D)           (None, 55, 55, 80)           5120      ['max_pooling2d[0][0]']
#
#  batch_normalization_3 (Bat  (None, 55, 55, 80)           240       ['conv2d_3[0][0]']
#  chNormalization)
#
#  activation_3 (Activation)   (None, 55, 55, 80)           0         ['batch_normalization_3[0][0]'
#                                                                     ]
#
#  conv2d_4 (Conv2D)           (None, 53, 53, 192)          138240    ['activation_3[0][0]']
#
#  batch_normalization_4 (Bat  (None, 53, 53, 192)          576       ['conv2d_4[0][0]']
#  chNormalization)
#
#  activation_4 (Activation)   (None, 53, 53, 192)          0         ['batch_normalization_4[0][0]'
#                                                                     ]
#
#  max_pooling2d_1 (MaxPoolin  (None, 26, 26, 192)          0         ['activation_4[0][0]']
#  g2D)
#
#  conv2d_8 (Conv2D)           (None, 26, 26, 64)           12288     ['max_pooling2d_1[0][0]']
#
#  batch_normalization_8 (Bat  (None, 26, 26, 64)           192       ['conv2d_8[0][0]']
#  chNormalization)
#
#  activation_8 (Activation)   (None, 26, 26, 64)           0         ['batch_normalization_8[0][0]'
#                                                                     ]
#
#  conv2d_6 (Conv2D)           (None, 26, 26, 48)           9216      ['max_pooling2d_1[0][0]']
#
#  conv2d_9 (Conv2D)           (None, 26, 26, 96)           55296     ['activation_8[0][0]']
#
#  batch_normalization_6 (Bat  (None, 26, 26, 48)           144       ['conv2d_6[0][0]']
#  chNormalization)
#
#  batch_normalization_9 (Bat  (None, 26, 26, 96)           288       ['conv2d_9[0][0]']
#  chNormalization)
#
#  activation_6 (Activation)   (None, 26, 26, 48)           0         ['batch_normalization_6[0][0]'
#                                                                     ]
#
#  activation_9 (Activation)   (None, 26, 26, 96)           0         ['batch_normalization_9[0][0]'
#                                                                     ]
#
#  average_pooling2d (Average  (None, 26, 26, 192)          0         ['max_pooling2d_1[0][0]']
#  Pooling2D)
#
#  conv2d_5 (Conv2D)           (None, 26, 26, 96)           18432     ['max_pooling2d_1[0][0]']
#
#  conv2d_7 (Conv2D)           (None, 26, 26, 64)           76800     ['activation_6[0][0]']
#
#  conv2d_10 (Conv2D)          (None, 26, 26, 96)           82944     ['activation_9[0][0]']
#
#  conv2d_11 (Conv2D)          (None, 26, 26, 64)           12288     ['average_pooling2d[0][0]']
#
#  batch_normalization_5 (Bat  (None, 26, 26, 96)           288       ['conv2d_5[0][0]']
#  chNormalization)
#
#  batch_normalization_7 (Bat  (None, 26, 26, 64)           192       ['conv2d_7[0][0]']
#  chNormalization)
#
#  batch_normalization_10 (Ba  (None, 26, 26, 96)           288       ['conv2d_10[0][0]']
#  tchNormalization)
#
#  batch_normalization_11 (Ba  (None, 26, 26, 64)           192       ['conv2d_11[0][0]']
#  tchNormalization)
#
#  activation_5 (Activation)   (None, 26, 26, 96)           0         ['batch_normalization_5[0][0]'
#                                                                     ]
#
#  activation_7 (Activation)   (None, 26, 26, 64)           0         ['batch_normalization_7[0][0]'
#                                                                     ]
#
#  activation_10 (Activation)  (None, 26, 26, 96)           0         ['batch_normalization_10[0][0]
#                                                                     ']
#
#  activation_11 (Activation)  (None, 26, 26, 64)           0         ['batch_normalization_11[0][0]
#                                                                     ']
#
#  mixed_5b (Concatenate)      (None, 26, 26, 320)          0         ['activation_5[0][0]',
#                                                                      'activation_7[0][0]',
#                                                                      'activation_10[0][0]',
#                                                                      'activation_11[0][0]']
#
#  conv2d_15 (Conv2D)          (None, 26, 26, 32)           10240     ['mixed_5b[0][0]']
#
#  batch_normalization_15 (Ba  (None, 26, 26, 32)           96        ['conv2d_15[0][0]']
#  tchNormalization)
#
#  activation_15 (Activation)  (None, 26, 26, 32)           0         ['batch_normalization_15[0][0]
#                                                                     ']
#
#  conv2d_13 (Conv2D)          (None, 26, 26, 32)           10240     ['mixed_5b[0][0]']
#
#  conv2d_16 (Conv2D)          (None, 26, 26, 48)           13824     ['activation_15[0][0]']
#
#  batch_normalization_13 (Ba  (None, 26, 26, 32)           96        ['conv2d_13[0][0]']
#  tchNormalization)
#
#  batch_normalization_16 (Ba  (None, 26, 26, 48)           144       ['conv2d_16[0][0]']
#  tchNormalization)
#
#  activation_13 (Activation)  (None, 26, 26, 32)           0         ['batch_normalization_13[0][0]
#                                                                     ']
#
#  activation_16 (Activation)  (None, 26, 26, 48)           0         ['batch_normalization_16[0][0]
#                                                                     ']
#
#  conv2d_12 (Conv2D)          (None, 26, 26, 32)           10240     ['mixed_5b[0][0]']
#
#  conv2d_14 (Conv2D)          (None, 26, 26, 32)           9216      ['activation_13[0][0]']
#
#  conv2d_17 (Conv2D)          (None, 26, 26, 64)           27648     ['activation_16[0][0]']
#
#  batch_normalization_12 (Ba  (None, 26, 26, 32)           96        ['conv2d_12[0][0]']
#  tchNormalization)
#
#  batch_normalization_14 (Ba  (None, 26, 26, 32)           96        ['conv2d_14[0][0]']
#  tchNormalization)
#
#  batch_normalization_17 (Ba  (None, 26, 26, 64)           192       ['conv2d_17[0][0]']
#  tchNormalization)
#
#  activation_12 (Activation)  (None, 26, 26, 32)           0         ['batch_normalization_12[0][0]
#                                                                     ']
#
#  activation_14 (Activation)  (None, 26, 26, 32)           0         ['batch_normalization_14[0][0]
#                                                                     ']
#
#  activation_17 (Activation)  (None, 26, 26, 64)           0         ['batch_normalization_17[0][0]
#                                                                     ']
#
#  block35_1_mixed (Concatena  (None, 26, 26, 128)          0         ['activation_12[0][0]',
#  te)                                                                 'activation_14[0][0]',
#                                                                      'activation_17[0][0]']
#
#  block35_1_conv (Conv2D)     (None, 26, 26, 320)          41280     ['block35_1_mixed[0][0]']
#
#  custom_scale_layer (Custom  (None, 26, 26, 320)          0         ['mixed_5b[0][0]',
#  ScaleLayer)                                                         'block35_1_conv[0][0]']
#
#  block35_1_ac (Activation)   (None, 26, 26, 320)          0         ['custom_scale_layer[0][0]']
#
#  conv2d_21 (Conv2D)          (None, 26, 26, 32)           10240     ['block35_1_ac[0][0]']
#
#  batch_normalization_21 (Ba  (None, 26, 26, 32)           96        ['conv2d_21[0][0]']
#  tchNormalization)
#
#  activation_21 (Activation)  (None, 26, 26, 32)           0         ['batch_normalization_21[0][0]
#                                                                     ']
#
#  conv2d_19 (Conv2D)          (None, 26, 26, 32)           10240     ['block35_1_ac[0][0]']
#
#  conv2d_22 (Conv2D)          (None, 26, 26, 48)           13824     ['activation_21[0][0]']
#
#  batch_normalization_19 (Ba  (None, 26, 26, 32)           96        ['conv2d_19[0][0]']
#  tchNormalization)
#
#  batch_normalization_22 (Ba  (None, 26, 26, 48)           144       ['conv2d_22[0][0]']
#  tchNormalization)
#
#  activation_19 (Activation)  (None, 26, 26, 32)           0         ['batch_normalization_19[0][0]
#                                                                     ']
#
#  activation_22 (Activation)  (None, 26, 26, 48)           0         ['batch_normalization_22[0][0]
#                                                                     ']
#
#  conv2d_18 (Conv2D)          (None, 26, 26, 32)           10240     ['block35_1_ac[0][0]']
#
#  conv2d_20 (Conv2D)          (None, 26, 26, 32)           9216      ['activation_19[0][0]']
#
#  conv2d_23 (Conv2D)          (None, 26, 26, 64)           27648     ['activation_22[0][0]']
#
#  batch_normalization_18 (Ba  (None, 26, 26, 32)           96        ['conv2d_18[0][0]']
#  tchNormalization)
#
#  batch_normalization_20 (Ba  (None, 26, 26, 32)           96        ['conv2d_20[0][0]']
#  tchNormalization)
#
#  batch_normalization_23 (Ba  (None, 26, 26, 64)           192       ['conv2d_23[0][0]']
#  tchNormalization)
#
#  activation_18 (Activation)  (None, 26, 26, 32)           0         ['batch_normalization_18[0][0]
#                                                                     ']
#
#  activation_20 (Activation)  (None, 26, 26, 32)           0         ['batch_normalization_20[0][0]
#                                                                     ']
#
#  activation_23 (Activation)  (None, 26, 26, 64)           0         ['batch_normalization_23[0][0]
#                                                                     ']
#
#  block35_2_mixed (Concatena  (None, 26, 26, 128)          0         ['activation_18[0][0]',
#  te)                                                                 'activation_20[0][0]',
#                                                                      'activation_23[0][0]']
#
#  block35_2_conv (Conv2D)     (None, 26, 26, 320)          41280     ['block35_2_mixed[0][0]']
#
#  custom_scale_layer_1 (Cust  (None, 26, 26, 320)          0         ['block35_1_ac[0][0]',
#  omScaleLayer)                                                       'block35_2_conv[0][0]']
#
#  block35_2_ac (Activation)   (None, 26, 26, 320)          0         ['custom_scale_layer_1[0][0]']
#
#  conv2d_27 (Conv2D)          (None, 26, 26, 32)           10240     ['block35_2_ac[0][0]']
#
#  batch_normalization_27 (Ba  (None, 26, 26, 32)           96        ['conv2d_27[0][0]']
#  tchNormalization)
#
#  activation_27 (Activation)  (None, 26, 26, 32)           0         ['batch_normalization_27[0][0]
#                                                                     ']
#
#  conv2d_25 (Conv2D)          (None, 26, 26, 32)           10240     ['block35_2_ac[0][0]']
#
#  conv2d_28 (Conv2D)          (None, 26, 26, 48)           13824     ['activation_27[0][0]']
#
#  batch_normalization_25 (Ba  (None, 26, 26, 32)           96        ['conv2d_25[0][0]']
#  tchNormalization)
#
#  batch_normalization_28 (Ba  (None, 26, 26, 48)           144       ['conv2d_28[0][0]']
#  tchNormalization)
#
#  activation_25 (Activation)  (None, 26, 26, 32)           0         ['batch_normalization_25[0][0]
#                                                                     ']
#
#  activation_28 (Activation)  (None, 26, 26, 48)           0         ['batch_normalization_28[0][0]
#                                                                     ']
#
#  conv2d_24 (Conv2D)          (None, 26, 26, 32)           10240     ['block35_2_ac[0][0]']
#
#  conv2d_26 (Conv2D)          (None, 26, 26, 32)           9216      ['activation_25[0][0]']
#
#  conv2d_29 (Conv2D)          (None, 26, 26, 64)           27648     ['activation_28[0][0]']
#
#  batch_normalization_24 (Ba  (None, 26, 26, 32)           96        ['conv2d_24[0][0]']
#  tchNormalization)
#
#  batch_normalization_26 (Ba  (None, 26, 26, 32)           96        ['conv2d_26[0][0]']
#  tchNormalization)
#
#  batch_normalization_29 (Ba  (None, 26, 26, 64)           192       ['conv2d_29[0][0]']
#  tchNormalization)
#
#  activation_24 (Activation)  (None, 26, 26, 32)           0         ['batch_normalization_24[0][0]
#                                                                     ']
#
#  activation_26 (Activation)  (None, 26, 26, 32)           0         ['batch_normalization_26[0][0]
#                                                                     ']
#
#  activation_29 (Activation)  (None, 26, 26, 64)           0         ['batch_normalization_29[0][0]
#                                                                     ']
#
#  block35_3_mixed (Concatena  (None, 26, 26, 128)          0         ['activation_24[0][0]',
#  te)                                                                 'activation_26[0][0]',
#                                                                      'activation_29[0][0]']
#
#  block35_3_conv (Conv2D)     (None, 26, 26, 320)          41280     ['block35_3_mixed[0][0]']
#
#  custom_scale_layer_2 (Cust  (None, 26, 26, 320)          0         ['block35_2_ac[0][0]',
#  omScaleLayer)                                                       'block35_3_conv[0][0]']
#
#  block35_3_ac (Activation)   (None, 26, 26, 320)          0         ['custom_scale_layer_2[0][0]']
#
#  conv2d_33 (Conv2D)          (None, 26, 26, 32)           10240     ['block35_3_ac[0][0]']
#
#  batch_normalization_33 (Ba  (None, 26, 26, 32)           96        ['conv2d_33[0][0]']
#  tchNormalization)
#
#  activation_33 (Activation)  (None, 26, 26, 32)           0         ['batch_normalization_33[0][0]
#                                                                     ']
#
#  conv2d_31 (Conv2D)          (None, 26, 26, 32)           10240     ['block35_3_ac[0][0]']
#
#  conv2d_34 (Conv2D)          (None, 26, 26, 48)           13824     ['activation_33[0][0]']
#
#  batch_normalization_31 (Ba  (None, 26, 26, 32)           96        ['conv2d_31[0][0]']
#  tchNormalization)
#
#  batch_normalization_34 (Ba  (None, 26, 26, 48)           144       ['conv2d_34[0][0]']
#  tchNormalization)
#
#  activation_31 (Activation)  (None, 26, 26, 32)           0         ['batch_normalization_31[0][0]
#                                                                     ']
#
#  activation_34 (Activation)  (None, 26, 26, 48)           0         ['batch_normalization_34[0][0]
#                                                                     ']
#
#  conv2d_30 (Conv2D)          (None, 26, 26, 32)           10240     ['block35_3_ac[0][0]']
#
#  conv2d_32 (Conv2D)          (None, 26, 26, 32)           9216      ['activation_31[0][0]']
#
#  conv2d_35 (Conv2D)          (None, 26, 26, 64)           27648     ['activation_34[0][0]']
#
#  batch_normalization_30 (Ba  (None, 26, 26, 32)           96        ['conv2d_30[0][0]']
#  tchNormalization)
#
#  batch_normalization_32 (Ba  (None, 26, 26, 32)           96        ['conv2d_32[0][0]']
#  tchNormalization)
#
#  batch_normalization_35 (Ba  (None, 26, 26, 64)           192       ['conv2d_35[0][0]']
#  tchNormalization)
#
#  activation_30 (Activation)  (None, 26, 26, 32)           0         ['batch_normalization_30[0][0]
#                                                                     ']
#
#  activation_32 (Activation)  (None, 26, 26, 32)           0         ['batch_normalization_32[0][0]
#                                                                     ']
#
#  activation_35 (Activation)  (None, 26, 26, 64)           0         ['batch_normalization_35[0][0]
#                                                                     ']
#
#  block35_4_mixed (Concatena  (None, 26, 26, 128)          0         ['activation_30[0][0]',
#  te)                                                                 'activation_32[0][0]',
#                                                                      'activation_35[0][0]']
#
#  block35_4_conv (Conv2D)     (None, 26, 26, 320)          41280     ['block35_4_mixed[0][0]']
#
#  custom_scale_layer_3 (Cust  (None, 26, 26, 320)          0         ['block35_3_ac[0][0]',
#  omScaleLayer)                                                       'block35_4_conv[0][0]']
#
#  block35_4_ac (Activation)   (None, 26, 26, 320)          0         ['custom_scale_layer_3[0][0]']
#
#  conv2d_39 (Conv2D)          (None, 26, 26, 32)           10240     ['block35_4_ac[0][0]']
#
#  batch_normalization_39 (Ba  (None, 26, 26, 32)           96        ['conv2d_39[0][0]']
#  tchNormalization)
#
#  activation_39 (Activation)  (None, 26, 26, 32)           0         ['batch_normalization_39[0][0]
#                                                                     ']
#
#  conv2d_37 (Conv2D)          (None, 26, 26, 32)           10240     ['block35_4_ac[0][0]']
#
#  conv2d_40 (Conv2D)          (None, 26, 26, 48)           13824     ['activation_39[0][0]']
#
#  batch_normalization_37 (Ba  (None, 26, 26, 32)           96        ['conv2d_37[0][0]']
#  tchNormalization)
#
#  batch_normalization_40 (Ba  (None, 26, 26, 48)           144       ['conv2d_40[0][0]']
#  tchNormalization)
#
#  activation_37 (Activation)  (None, 26, 26, 32)           0         ['batch_normalization_37[0][0]
#                                                                     ']
#
#  activation_40 (Activation)  (None, 26, 26, 48)           0         ['batch_normalization_40[0][0]
#                                                                     ']
#
#  conv2d_36 (Conv2D)          (None, 26, 26, 32)           10240     ['block35_4_ac[0][0]']
#
#  conv2d_38 (Conv2D)          (None, 26, 26, 32)           9216      ['activation_37[0][0]']
#
#  conv2d_41 (Conv2D)          (None, 26, 26, 64)           27648     ['activation_40[0][0]']
#
#  batch_normalization_36 (Ba  (None, 26, 26, 32)           96        ['conv2d_36[0][0]']
#  tchNormalization)
#
#  batch_normalization_38 (Ba  (None, 26, 26, 32)           96        ['conv2d_38[0][0]']
#  tchNormalization)
#
#  batch_normalization_41 (Ba  (None, 26, 26, 64)           192       ['conv2d_41[0][0]']
#  tchNormalization)
#
#  activation_36 (Activation)  (None, 26, 26, 32)           0         ['batch_normalization_36[0][0]
#                                                                     ']
#
#  activation_38 (Activation)  (None, 26, 26, 32)           0         ['batch_normalization_38[0][0]
#                                                                     ']
#
#  activation_41 (Activation)  (None, 26, 26, 64)           0         ['batch_normalization_41[0][0]
#                                                                     ']
#
#  block35_5_mixed (Concatena  (None, 26, 26, 128)          0         ['activation_36[0][0]',
#  te)                                                                 'activation_38[0][0]',
#                                                                      'activation_41[0][0]']
#
#  block35_5_conv (Conv2D)     (None, 26, 26, 320)          41280     ['block35_5_mixed[0][0]']
#
#  custom_scale_layer_4 (Cust  (None, 26, 26, 320)          0         ['block35_4_ac[0][0]',
#  omScaleLayer)                                                       'block35_5_conv[0][0]']
#
#  block35_5_ac (Activation)   (None, 26, 26, 320)          0         ['custom_scale_layer_4[0][0]']
#
#  conv2d_45 (Conv2D)          (None, 26, 26, 32)           10240     ['block35_5_ac[0][0]']
#
#  batch_normalization_45 (Ba  (None, 26, 26, 32)           96        ['conv2d_45[0][0]']
#  tchNormalization)
#
#  activation_45 (Activation)  (None, 26, 26, 32)           0         ['batch_normalization_45[0][0]
#                                                                     ']
#
#  conv2d_43 (Conv2D)          (None, 26, 26, 32)           10240     ['block35_5_ac[0][0]']
#
#  conv2d_46 (Conv2D)          (None, 26, 26, 48)           13824     ['activation_45[0][0]']
#
#  batch_normalization_43 (Ba  (None, 26, 26, 32)           96        ['conv2d_43[0][0]']
#  tchNormalization)
#
#  batch_normalization_46 (Ba  (None, 26, 26, 48)           144       ['conv2d_46[0][0]']
#  tchNormalization)
#
#  activation_43 (Activation)  (None, 26, 26, 32)           0         ['batch_normalization_43[0][0]
#                                                                     ']
#
#  activation_46 (Activation)  (None, 26, 26, 48)           0         ['batch_normalization_46[0][0]
#                                                                     ']
#
#  conv2d_42 (Conv2D)          (None, 26, 26, 32)           10240     ['block35_5_ac[0][0]']
#
#  conv2d_44 (Conv2D)          (None, 26, 26, 32)           9216      ['activation_43[0][0]']
#
#  conv2d_47 (Conv2D)          (None, 26, 26, 64)           27648     ['activation_46[0][0]']
#
#  batch_normalization_42 (Ba  (None, 26, 26, 32)           96        ['conv2d_42[0][0]']
#  tchNormalization)
#
#  batch_normalization_44 (Ba  (None, 26, 26, 32)           96        ['conv2d_44[0][0]']
#  tchNormalization)
#
#  batch_normalization_47 (Ba  (None, 26, 26, 64)           192       ['conv2d_47[0][0]']
#  tchNormalization)
#
#  activation_42 (Activation)  (None, 26, 26, 32)           0         ['batch_normalization_42[0][0]
#                                                                     ']
#
#  activation_44 (Activation)  (None, 26, 26, 32)           0         ['batch_normalization_44[0][0]
#                                                                     ']
#
#  activation_47 (Activation)  (None, 26, 26, 64)           0         ['batch_normalization_47[0][0]
#                                                                     ']
#
#  block35_6_mixed (Concatena  (None, 26, 26, 128)          0         ['activation_42[0][0]',
#  te)                                                                 'activation_44[0][0]',
#                                                                      'activation_47[0][0]']
#
#  block35_6_conv (Conv2D)     (None, 26, 26, 320)          41280     ['block35_6_mixed[0][0]']
#
#  custom_scale_layer_5 (Cust  (None, 26, 26, 320)          0         ['block35_5_ac[0][0]',
#  omScaleLayer)                                                       'block35_6_conv[0][0]']
#
#  block35_6_ac (Activation)   (None, 26, 26, 320)          0         ['custom_scale_layer_5[0][0]']
#
#  conv2d_51 (Conv2D)          (None, 26, 26, 32)           10240     ['block35_6_ac[0][0]']
#
#  batch_normalization_51 (Ba  (None, 26, 26, 32)           96        ['conv2d_51[0][0]']
#  tchNormalization)
#
#  activation_51 (Activation)  (None, 26, 26, 32)           0         ['batch_normalization_51[0][0]
#                                                                     ']
#
#  conv2d_49 (Conv2D)          (None, 26, 26, 32)           10240     ['block35_6_ac[0][0]']
#
#  conv2d_52 (Conv2D)          (None, 26, 26, 48)           13824     ['activation_51[0][0]']
#
#  batch_normalization_49 (Ba  (None, 26, 26, 32)           96        ['conv2d_49[0][0]']
#  tchNormalization)
# ...
#  batch_normalization_187 (B  (None, 5, 5, 192)            576       ['conv2d_187[0][0]']
#  atchNormalization)
#
#  batch_normalization_190 (B  (None, 5, 5, 256)            768       ['conv2d_190[0][0]']
#  atchNormalization)
#
#  activation_187 (Activation  (None, 5, 5, 192)            0         ['batch_normalization_187[0][0
#  )                                                                  ]']
#
#  activation_190 (Activation  (None, 5, 5, 256)            0         ['batch_normalization_190[0][0
#  )                                                                  ]']
#
#  block8_7_mixed (Concatenat  (None, 5, 5, 448)            0         ['activation_187[0][0]',
#  e)                                                                  'activation_190[0][0]']
#
#  block8_7_conv (Conv2D)      (None, 5, 5, 2080)           933920    ['block8_7_mixed[0][0]']
#
#  custom_scale_layer_36 (Cus  (None, 5, 5, 2080)           0         ['block8_6_ac[0][0]',
#  tomScaleLayer)                                                      'block8_7_conv[0][0]']
#
#  block8_7_ac (Activation)    (None, 5, 5, 2080)           0         ['custom_scale_layer_36[0][0]'
#                                                                     ]
#
#  conv2d_192 (Conv2D)         (None, 5, 5, 192)            399360    ['block8_7_ac[0][0]']
#
#  batch_normalization_192 (B  (None, 5, 5, 192)            576       ['conv2d_192[0][0]']
#  atchNormalization)
#
#  activation_192 (Activation  (None, 5, 5, 192)            0         ['batch_normalization_192[0][0
#  )                                                                  ]']
#
#  conv2d_193 (Conv2D)         (None, 5, 5, 224)            129024    ['activation_192[0][0]']
#
#  batch_normalization_193 (B  (None, 5, 5, 224)            672       ['conv2d_193[0][0]']
#  atchNormalization)
#
#  activation_193 (Activation  (None, 5, 5, 224)            0         ['batch_normalization_193[0][0
#  )                                                                  ]']
#
#  conv2d_191 (Conv2D)         (None, 5, 5, 192)            399360    ['block8_7_ac[0][0]']
#
#  conv2d_194 (Conv2D)         (None, 5, 5, 256)            172032    ['activation_193[0][0]']
#
#  batch_normalization_191 (B  (None, 5, 5, 192)            576       ['conv2d_191[0][0]']
#  atchNormalization)
#
#  batch_normalization_194 (B  (None, 5, 5, 256)            768       ['conv2d_194[0][0]']
#  atchNormalization)
#
#  activation_191 (Activation  (None, 5, 5, 192)            0         ['batch_normalization_191[0][0
#  )                                                                  ]']
#
#  activation_194 (Activation  (None, 5, 5, 256)            0         ['batch_normalization_194[0][0
#  )                                                                  ]']
#
#  block8_8_mixed (Concatenat  (None, 5, 5, 448)            0         ['activation_191[0][0]',
#  e)                                                                  'activation_194[0][0]']
#
#  block8_8_conv (Conv2D)      (None, 5, 5, 2080)           933920    ['block8_8_mixed[0][0]']
#
#  custom_scale_layer_37 (Cus  (None, 5, 5, 2080)           0         ['block8_7_ac[0][0]',
#  tomScaleLayer)                                                      'block8_8_conv[0][0]']
#
#  block8_8_ac (Activation)    (None, 5, 5, 2080)           0         ['custom_scale_layer_37[0][0]'
#                                                                     ]
#
#  conv2d_196 (Conv2D)         (None, 5, 5, 192)            399360    ['block8_8_ac[0][0]']
#
#  batch_normalization_196 (B  (None, 5, 5, 192)            576       ['conv2d_196[0][0]']
#  atchNormalization)
#
#  activation_196 (Activation  (None, 5, 5, 192)            0         ['batch_normalization_196[0][0
#  )                                                                  ]']
#
#  conv2d_197 (Conv2D)         (None, 5, 5, 224)            129024    ['activation_196[0][0]']
#
#  batch_normalization_197 (B  (None, 5, 5, 224)            672       ['conv2d_197[0][0]']
#  atchNormalization)
#
#  activation_197 (Activation  (None, 5, 5, 224)            0         ['batch_normalization_197[0][0
#  )                                                                  ]']
#
#  conv2d_195 (Conv2D)         (None, 5, 5, 192)            399360    ['block8_8_ac[0][0]']
#
#  conv2d_198 (Conv2D)         (None, 5, 5, 256)            172032    ['activation_197[0][0]']
#
#  batch_normalization_195 (B  (None, 5, 5, 192)            576       ['conv2d_195[0][0]']
#  atchNormalization)
#
#  batch_normalization_198 (B  (None, 5, 5, 256)            768       ['conv2d_198[0][0]']
#  atchNormalization)
#
#  activation_195 (Activation  (None, 5, 5, 192)            0         ['batch_normalization_195[0][0
#  )                                                                  ]']
#
#  activation_198 (Activation  (None, 5, 5, 256)            0         ['batch_normalization_198[0][0
#  )                                                                  ]']
#
#  block8_9_mixed (Concatenat  (None, 5, 5, 448)            0         ['activation_195[0][0]',
#  e)                                                                  'activation_198[0][0]']
#
#  block8_9_conv (Conv2D)      (None, 5, 5, 2080)           933920    ['block8_9_mixed[0][0]']
#
#  custom_scale_layer_38 (Cus  (None, 5, 5, 2080)           0         ['block8_8_ac[0][0]',
#  tomScaleLayer)                                                      'block8_9_conv[0][0]']
#
#  block8_9_ac (Activation)    (None, 5, 5, 2080)           0         ['custom_scale_layer_38[0][0]'
#                                                                     ]
#
#  conv2d_200 (Conv2D)         (None, 5, 5, 192)            399360    ['block8_9_ac[0][0]']
#
#  batch_normalization_200 (B  (None, 5, 5, 192)            576       ['conv2d_200[0][0]']
#  atchNormalization)
#
#  activation_200 (Activation  (None, 5, 5, 192)            0         ['batch_normalization_200[0][0
#  )                                                                  ]']
#
#  conv2d_201 (Conv2D)         (None, 5, 5, 224)            129024    ['activation_200[0][0]']
#
#  batch_normalization_201 (B  (None, 5, 5, 224)            672       ['conv2d_201[0][0]']
#  atchNormalization)
#
#  activation_201 (Activation  (None, 5, 5, 224)            0         ['batch_normalization_201[0][0
#  )                                                                  ]']
#
#  conv2d_199 (Conv2D)         (None, 5, 5, 192)            399360    ['block8_9_ac[0][0]']
#
#  conv2d_202 (Conv2D)         (None, 5, 5, 256)            172032    ['activation_201[0][0]']
#
#  batch_normalization_199 (B  (None, 5, 5, 192)            576       ['conv2d_199[0][0]']
#  atchNormalization)
#
#  batch_normalization_202 (B  (None, 5, 5, 256)            768       ['conv2d_202[0][0]']
#  atchNormalization)
#
#  activation_199 (Activation  (None, 5, 5, 192)            0         ['batch_normalization_199[0][0
#  )                                                                  ]']
#
#  activation_202 (Activation  (None, 5, 5, 256)            0         ['batch_normalization_202[0][0
#  )                                                                  ]']
#
#  block8_10_mixed (Concatena  (None, 5, 5, 448)            0         ['activation_199[0][0]',
#  te)                                                                 'activation_202[0][0]']
#
#  block8_10_conv (Conv2D)     (None, 5, 5, 2080)           933920    ['block8_10_mixed[0][0]']
#
#  custom_scale_layer_39 (Cus  (None, 5, 5, 2080)           0         ['block8_9_ac[0][0]',
#  tomScaleLayer)                                                      'block8_10_conv[0][0]']
#
#  conv_7b (Conv2D)            (None, 5, 5, 1536)           3194880   ['custom_scale_layer_39[0][0]'
#                                                                     ]
#
#  conv_7b_bn (BatchNormaliza  (None, 5, 5, 1536)           4608      ['conv_7b[0][0]']
#  tion)
#
#  conv_7b_ac (Activation)     (None, 5, 5, 1536)           0         ['conv_7b_bn[0][0]']
#
# ==================================================================================================
# Total params: 54336736 (207.28 MB)
# Trainable params: 54276192 (207.05 MB)
# Non-trainable params: 60544 (236.50 KB)
# __________________________________________________________________________________________________
# <class 'keras.src.engine.functional.Functional'>

# %% [markdown]
# # Build Model and Training

# %%
# Build the Model
model = models.Model(inputs=base_model.input, outputs=base_model.output)
model.trainable = False

# Add GlobalAveragePooling2D and Dense layer for classification
x = layers.GlobalAveragePooling2D()(model.output)
x = layers.Dense(3, activation='softmax')(x)

# Final model
final_model = models.Model(inputs=model.input, outputs=x)

# Compile Model
final_model.compile(optimizer='adam', loss='categorical_crossentropy', metrics=['accuracy'])

# Add Early Stopping Callback
early_stopping = tf.keras.callbacks.EarlyStopping(monitor='val_loss', patience=6, restore_best_weights=True)

# Train Model
steps_per_epoch = math.ceil(train_batches.samples / train_batches.batch_size)
validation_steps = math.ceil(valid_batches.samples / valid_batches.batch_size)

history = final_model.fit(
    train_batches,
    validation_data=valid_batches,
    steps_per_epoch=steps_per_epoch,
    validation_steps=validation_steps,
    epochs=30,
    verbose=1,
    callbacks=[early_stopping]
)
# Out:
# Epoch 1/30
# 126/126 [==============================] - 1427s 11s/step - loss: 0.7463 - accuracy: 0.6634 - val_loss: 0.5550 - val_accuracy: 0.7593
# Epoch 2/30
# 126/126 [==============================] - 31s 242ms/step - loss: 0.4695 - accuracy: 0.8098 - val_loss: 0.4195 - val_accuracy: 0.8310
# Epoch 3/30
# 126/126 [==============================] - 34s 272ms/step - loss: 0.3793 - accuracy: 0.8539 - val_loss: 0.3727 - val_accuracy: 0.8598
# Epoch 4/30
# 126/126 [==============================] - 31s 247ms/step - loss: 0.3194 - accuracy: 0.8873 - val_loss: 0.3101 - val_accuracy: 0.8824
# Epoch 5/30
# 126/126 [==============================] - 31s 247ms/step - loss: 0.2767 - accuracy: 0.9110 - val_loss: 0.3028 - val_accuracy: 0.8832
# Epoch 6/30
# 126/126 [==============================] - 31s 246ms/step - loss: 0.2464 - accuracy: 0.9240 - val_loss: 0.3123 - val_accuracy: 0.8715
# Epoch 7/30
# 126/126 [==============================] - 31s 247ms/step - loss: 0.2263 - accuracy: 0.9292 - val_loss: 0.2384 - val_accuracy: 0.9221
# Epoch 8/30
# 126/126 [==============================] - 31s 247ms/step - loss: 0.2024 - accuracy: 0.9402 - val_loss: 0.2193 - val_accuracy: 0.9268
# Epoch 9/30
# 126/126 [==============================] - 33s 258ms/step - loss: 0.1928 - accuracy: 0.9414 - val_loss: 0.2020 - val_accuracy: 0.9338
# Epoch 10/30
# 126/126 [==============================] - 31s 246ms/step - loss: 0.1704 - accuracy: 0.9541 - val_loss: 0.1906 - val_accuracy: 0.9447
# Epoch 11/30
# 126/126 [==============================] - 31s 244ms/step - loss: 0.1560 - accuracy: 0.9636 - val_loss: 0.1954 - val_accuracy: 0.9377
# Epoch 12/30
# 126/126 [==============================] - 31s 245ms/step - loss: 0.1521 - accuracy: 0.9581 - val_loss: 0.1709 - val_accuracy: 0.9517
# Epoch 13/30
# 126/126 [==============================] - 34s 270ms/step - loss: 0.1392 - accuracy: 0.9678 - val_loss: 0.1637 - val_accuracy: 0.9556
# Epoch 14/30
# 126/126 [==============================] - 31s 243ms/step - loss: 0.1298 - accuracy: 0.9731 - val_loss: 0.1527 - val_accuracy: 0.9579
# Epoch 15/30
# 126/126 [==============================] - 31s 243ms/step - loss: 0.1223 - accuracy: 0.9743 - val_loss: 0.1522 - val_accuracy: 0.9650
# Epoch 16/30
# 126/126 [==============================] - 31s 245ms/step - loss: 0.1127 - accuracy: 0.9803 - val_loss: 0.1448 - val_accuracy: 0.9556
# Epoch 17/30
# 126/126 [==============================] - 31s 243ms/step - loss: 0.1138 - accuracy: 0.9733 - val_loss: 0.1642 - val_accuracy: 0.9439
# Epoch 18/30
# 126/126 [==============================] - 31s 247ms/step - loss: 0.1068 - accuracy: 0.9768 - val_loss: 0.1372 - val_accuracy: 0.9634
# Epoch 19/30
# 126/126 [==============================] - 31s 246ms/step - loss: 0.1006 - accuracy: 0.9806 - val_loss: 0.1214 - val_accuracy: 0.9751
# Epoch 20/30
# 126/126 [==============================] - 31s 243ms/step - loss: 0.0922 - accuracy: 0.9850 - val_loss: 0.1334 - val_accuracy: 0.9626
# Epoch 21/30
# 126/126 [==============================] - 31s 245ms/step - loss: 0.0926 - accuracy: 0.9816 - val_loss: 0.1148 - val_accuracy: 0.9735
# Epoch 22/30
# 126/126 [==============================] - 31s 242ms/step - loss: 0.0923 - accuracy: 0.9786 - val_loss: 0.1118 - val_accuracy: 0.9720
# Epoch 23/30
# 126/126 [==============================] - 31s 245ms/step - loss: 0.0846 - accuracy: 0.9845 - val_loss: 0.1046 - val_accuracy: 0.9759
# Epoch 24/30
# 126/126 [==============================] - 31s 244ms/step - loss: 0.0773 - accuracy: 0.9878 - val_loss: 0.1063 - val_accuracy: 0.9751
# Epoch 25/30
# 126/126 [==============================] - 34s 266ms/step - loss: 0.0761 - accuracy: 0.9880 - val_loss: 0.1048 - val_accuracy: 0.9751
# Epoch 26/30
# 126/126 [==============================] - 34s 270ms/step - loss: 0.0743 - accuracy: 0.9855 - val_loss: 0.0927 - val_accuracy: 0.9798
# Epoch 27/30
# 126/126 [==============================] - 31s 242ms/step - loss: 0.0675 - accuracy: 0.9885 - val_loss: 0.0931 - val_accuracy: 0.9798
# Epoch 28/30
# 126/126 [==============================] - 31s 243ms/step - loss: 0.0637 - accuracy: 0.9920 - val_loss: 0.0903 - val_accuracy: 0.9813
# Epoch 29/30
# 126/126 [==============================] - 31s 242ms/step - loss: 0.0638 - accuracy: 0.9903 - val_loss: 0.1057 - val_accuracy: 0.9688
# Epoch 30/30
# 126/126 [==============================] - 30s 241ms/step - loss: 0.0597 - accuracy: 0.9928 - val_loss: 0.1024 - val_accuracy: 0.9704

# %% [markdown]
# # Visualize Model Performance

# %%
# Plot accuracy
plt.plot(history.history['accuracy'], label='train accuracy')
plt.plot(history.history['val_accuracy'], label='validation accuracy')
plt.title('Accuracy')
plt.xlabel('Epochs')
plt.ylabel('Accuracy')
plt.legend()
plt.show()

# Plot loss
plt.plot(history.history['loss'], label='train loss')
plt.plot(history.history['val_loss'], label='validation loss')
plt.title('Loss')
plt.xlabel('Epochs')
plt.ylabel('Loss')
plt.legend()
plt.show()

# %% [markdown]
# # Evaluate the Model

# %%
test_loss, test_accuracy = final_model.evaluate(test_batches, verbose=1)
print(f"Test Accuracy: {test_accuracy:.4f}")
print(f"Test Loss: {test_loss:.4f}")
# Out:
# 41/41 [==============================] - 497s 12s/step - loss: 0.0858 - accuracy: 0.9814
# Test Accuracy: 0.9814
# Test Loss: 0.0858

# %% [markdown]
# # Predict on Test Data

# %%
# Get the class labels
class_labels = list(test_batches.class_indices.keys())

# Reset the test_batches generator
test_batches.reset()

# Predict on the test data
predictions = final_model.predict(test_batches, verbose=1)
predicted_classes = np.argmax(predictions, axis=1)

# True labels
true_classes = test_batches.classes

# Confusion matrix
conf_matrix = confusion_matrix(true_classes, predicted_classes)
print('Confusion Matrix')
print(conf_matrix)

# Classification report
report = classification_report(true_classes, predicted_classes, target_names=class_labels)
print('Classification Report')
print(report)

# Plot confusion matrix
plt.figure(figsize=(10, 8))
sns.heatmap(conf_matrix, annot=True, fmt='d', cmap='Blues', xticklabels=class_labels, yticklabels=class_labels)
plt.xlabel('Predicted')
plt.ylabel('True')
plt.title('Confusion Matrix')
plt.show()
# Out:
# 41/41 [==============================] - 11s 194ms/step
# Confusion Matrix
# [[359  15   4]
#  [  1 450   3]
#  [  0   1 457]]
# Classification Report
#               precision    recall  f1-score   support
#
#     Immature       1.00      0.95      0.97       378
#       Mature       0.97      0.99      0.98       454
#       Normal       0.98      1.00      0.99       458
#
#     accuracy                           0.98      1290
#    macro avg       0.98      0.98      0.98      1290
# weighted avg       0.98      0.98      0.98      1290

# %% [markdown]
# # Interactive Image Classification

# %%
from tensorflow.keras.preprocessing import image
import matplotlib.pyplot as plt
from ipywidgets import widgets
from IPython.display import display

# Function to load and preprocess the image
def load_and_preprocess_image(image_path):
    # Load the image with the target size of 299x299
    img = image.load_img(image_path, target_size=(229, 229))
    # Convert the image to an array
    img_array = image.img_to_array(img)
    # Expand dimensions to match the input shape of the model
    img_array = np.expand_dims(img_array, axis=0)
    # Preprocess the image using the Inception-ResNet-V2 preprocess function
    img_array = tf.keras.applications.inception_resnet_v2.preprocess_input(img_array)
    return img_array

# Function to predict the label of the image
def predict_image(image_path):
    # Load and preprocess the image
    img_array = load_and_preprocess_image(image_path)
    # Make a prediction using the final model
    single_prediction = final_model.predict(img_array)
    # Get the predicted class index
    predicted_class = np.argmax(single_prediction, axis=1)
    # Get the predicted label from the class labels
    predicted_label = class_labels[predicted_class[0]]
    return predicted_label

# File upload widget to upload images
upload_widget = widgets.FileUpload(accept='image/*', multiple=False)

# Callback function when a file is uploaded
def on_file_upload_change(change):
    for filename, file_info in upload_widget.value.items():
        # Save the uploaded file
        with open(filename, 'wb') as f:
            f.write(file_info['content'])
        # Display the uploaded image
        img = image.load_img(filename, target_size=(299, 299))
        plt.imshow(img)
        plt.axis('off')
        plt.show()
        # Make a prediction
        predicted_label = predict_image(filename)
        print(f"Predicted Label for {filename}: {predicted_label}")

# Observe changes in the file upload widget
upload_widget.observe(on_file_upload_change, names='value')
# Display the file upload widget
display(upload_widget)
# Out:
# FileUpload(value={}, accept='image/*', description='Upload')
# 1/1 [==============================] - 4s 4s/step
# Predicted Label for katarak.jpg: Mature
# 1/1 [==============================] - 0s 39ms/step
# Predicted Label for WhatsApp Image 2024-06-02 at 17.25.16_89102211.jpg: Normal
# 1/1 [==============================] - 0s 36ms/step
# Predicted Label for news24_coid_1594833706.jpeg: Normal
# 1/1 [==============================] - 0s 35ms/step
# Predicted Label for post-op.jpg: Immature

# %% [markdown]
# # Save the Model

# %%
import os

MODEL_BASE_PATH = "/content/drive/MyDrive/Bangkit 2024"
PROJECT_NAME = "H5"
SAVE_MODEL_NAME = "inceptionresnetv2.h5"
save_model_path = os.path.join(MODEL_BASE_PATH, PROJECT_NAME, SAVE_MODEL_NAME)
if os.path.exists(os.path.join(MODEL_BASE_PATH, PROJECT_NAME)) == False:
    os.makedirs(os.path.join(MODEL_BASE_PATH, PROJECT_NAME))

inception = InceptionResNetV2(weights='imagenet')

print('Saving Model At {}...'.format(save_model_path))
inception.save(save_model_path,include_optimizer=False)
# Out:
# Downloading data from https://storage.googleapis.com/tensorflow/keras-applications/inception_resnet_v2/inception_resnet_v2_weights_tf_dim_ordering_tf_kernels.h5
# 225209952/225209952 [==============================] - 6s 0us/step
# /usr/local/lib/python3.10/dist-packages/keras/src/engine/training.py:3103: UserWarning: You are saving your model as an HDF5 file via `model.save()`. This file format is considered legacy. We recommend using instead the native Keras format, e.g. `model.save('my_model.keras')`.
#   saving_api.save_model(
# WARNING:tensorflow:Compiled the loaded model, but the compiled metrics have yet to be built. `model.compile_metrics` will be empty until you train or evaluate the model.
# Saving Model At /content/drive/MyDrive/Bangkit 2024/H5/inceptionresnetv2.h5...
